# %% [markdown]
# Video game dataset  Dan Le 3/11/2019

# %%
import numpy as np
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/Users/danle/.local/share/virtualenvs/data_analysis-JR90oTg5/lib/python3.7/site-packages/pandas/__init__.py'>

# %%
vg_stats =pd.read_csv('vgsales.csv')

# %%
vg_stats
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# ...

# %%
vg_stats['Publisher'].mode()
# Out:
# 0    Electronic Arts
# dtype: object

# %%
vg_stats['Platform'].mode()
# Out:
# 0    DS
# dtype: object

# %%
vg_stats['Genre'].mode()
# Out:
# 0    Action
# dtype: object

# %%
vg_stats[:20]
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
vg_stats['NA_Sales'].median()
# Out:
# 0.08

# %%
vg_stats.loc[vg_stats['NA_Sales'] == 0.08][:10]
# Out:
#       Rank                                               Name Platform  \
# 446    447                                  Dragon Warrior IV      NES
# 497    498        World Soccer Winning Eleven 7 International      PS2
# 1617  1619                             Farming Simulator 2015       PC
# 1926  1928                          Pro Evolution Soccer 2008     X360
# 2067  2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# 2373  2375                           Phantasy Star Portable 2      PSP
# 2579  2581                               The Sims 2: Castaway      PSP
# 3186  3188                                     SingStar Queen      PS2
# 3503  3505                                         Top Spin 3      PS3
# 3703  3705               Sonic & All-Stars Racing Transformed      PS3
#
#         Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 446   1990.0  Role-Playing              Enix Corporation      0.08      0.00
# ...

# %%
standard_dev = vg_stats['NA_Sales'].std()

# %%
standard_dev
# Out:
# 0.8166830292988796

# %%
high_NA = vg_stats['NA_Sales'].max()

# %%
high_NA
# Out:
# 41.49

# %%
high_NA/ standard_dev
# Out:
# 50.80306374875828

# %%
nintendo_stats = vg_stats.loc[vg_stats['Platform'] == 'Wii']

# %%
nintendo_stats
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 13        14                                            Wii Fit      Wii
# 14        15                                       Wii Fit Plus      Wii
# 39        40                            Super Smash Bros. Brawl      Wii
# 48        49                                 Super Mario Galaxy      Wii
# 60        61                                       Just Dance 3      Wii
# 68        69                                       Just Dance 2      Wii
# 78        79                                          Wii Party      Wii
# ...

# %%
nintendo_mean= nintendo_stats['Global_Sales'].mean()

# %%
nintendo_mean
# Out:
# 0.6994037735849057

# %%
not_nintendo = vg_stats.loc[vg_stats['Platform'] != 'Wii']

# %%
not_nintendo
# Out:
#         Rank                                               Name Platform  \
# 1          2                                  Super Mario Bros.      NES
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# 12        13                        Pokemon Gold/Pokemon Silver       GB
# 15        16                                 Kinect Adventures!     X360
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 18        19                                  Super Mario World     SNES
# ...

# %%
not_nintendo['Global_Sales'].mean()
# Out:
# 0.5233896418516336

# %%
nintendo_mean
# Out:
# 0.6994037735849057

# %% [markdown]
# Worst NA sales

# %%
vg_stats['NA_Sales'][:10:-1]
# Out:
# 16597     0.01
# 16596     0.00
# 16595     0.00
# 16594     0.01
# 16593     0.01
# 16592     0.01
# 16591     0.01
# 16590     0.00
# 16589     0.00
# 16588     0.01
# 16587     0.00
# 16586     0.00
# 16585     0.01
# 16584     0.01
# 16583     0.01
# 16582     0.01
# 16581     0.00
# 16580     0.00
# 16579     0.01
# 16578     0.01
# 16577     0.00
# 16576     0.00
# 16575     0.00
# 16574     0.00
# 16573     0.01
# 16572     0.00
# 16571     0.00
# 16570     0.00
# 16569     0.01
# 16568     0.00
#          ...
# 40        5.98
# 39        6.75
# 38        6.99
# 37        5.54
# 36        8.52
# 35        8.25
# 34        4.99
# 33        5.77
# 32        5.17
# 31        9.67
# 30        5.89
# 29        9.03
# 28        6.85
# 27        3.44
# 26        5.57
# 25        6.06
# 24        8.41
# 23        9.63
# 22        9.54
# 21       10.83
# 20        6.42
# 19        4.75
# 18       12.78
# 17        9.43
# 16        7.01
# 15       14.97
# 14        9.09
# ...

# %% [markdown]
# highest JP sale

# %%
vg_stats['JP_Sales'].max()
# Out:
# 10.22

# %% [markdown]
# mean JP sales

# %%
vg_stats['JP_Sales'].mean()
# Out:
# 0.077781660441017
