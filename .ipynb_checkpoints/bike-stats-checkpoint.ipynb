# %%
import numpy as np
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/Users/danle/.local/share/virtualenvs/data_analysis-JR90oTg5/lib/python3.7/site-packages/pandas/__init__.py'>

# %%
weather_stats =pd.read_csv('weather.csv')

# %%
weather_stats
# Out:
#            Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0    10/13/2014                 71                62.0                54
# 1    10/14/2014                 63                59.0                55
# 2    10/15/2014                 62                58.0                54
# 3    10/16/2014                 71                61.0                52
# 4    10/17/2014                 64                60.0                57
# 5    10/18/2014                 68                64.0                59
# 6    10/19/2014                 73                64.0                55
# 7    10/20/2014                 66                60.0                55
# 8    10/21/2014                 64                58.0                55
# 9    10/22/2014                 60                58.0                57
# 10   10/23/2014                 62                55.0                50
# 11   10/24/2014                 60                56.0                51
# ...

# %%
station_stats = pd.read_csv('station.csv')

# %%
station_stats
# Out:
#    station_id                                               name        lat  \
# 0       BT-01                                 3rd Ave & Broad St  47.618418
# 1       BT-03                                  2nd Ave & Vine St  47.615829
# 2       BT-04                             6th Ave & Blanchard St  47.616094
# 3       BT-05                             2nd Ave & Blanchard St  47.613110
# 4      CBD-03                                 7th Ave & Union St  47.610731
# 5      CBD-04                                 Union St & 4th Ave  47.609221
# 6      CBD-05                                1st Ave & Marion St  47.604058
# 7      CBD-06                                2nd Ave & Spring St  47.605950
# 8      CBD-07                     City Hall / 4th Ave & James St  47.603509
# 9      CBD-13                                  2nd Ave & Pine St  47.610185
# 10      CD-01                            12th Ave & E Yesler Way  47.602103
# ...

# %%
trip_stats = pd.read_csv('trip.csv', error_bad_lines=False)
# Out:
# b'Skipping line 50794: expected 12 fields, saw 20\n'

# %%
trip_stats
# Out:
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 0           431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1           432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2           433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3           434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4           435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# 5           436  10/13/2014 10:34  10/13/2014 10:47  SEA00337       808.805
# 6           437  10/13/2014 11:35  10/13/2014 11:45  SEA00202       596.715
# 7           438  10/13/2014 11:35  10/13/2014 11:45  SEA00311       592.131
# 8           439  10/13/2014 11:35  10/13/2014 11:45  SEA00486       586.347
# 9           440  10/13/2014 11:35  10/13/2014 11:45  SEA00434       587.634
# 10          441  10/13/2014 11:36  10/13/2014 11:45  SEA00195       564.899
# ...

# %% [markdown]
# Average trip duration for borrowed bicycles

# %%
trip_stats.tripduration.mean()
# Out:
# 1178.2956753399776

# %% [markdown]
# average age of people

# %%
mean_birthyear = trip_stats.birthyear.mode()

# %%
mean_birthyear
# Out:
# 0    1987.0
# dtype: float64

# %%
2019-mean_birthyear
# Out:
# 0    32.0
# dtype: float64

# %% [markdown]
# average and mean precipitation per month

# %%
weather_stats.Precipitation_In.mean()
# Out:
# 0.10506531204644412

# %%
weather_stats.Precipitation_In.median()
# Out:
# 0.0

# %% [markdown]
# average number of bikes given out

# %%
station_stats['install_dockcount'].mean()
# Out:
# 17.586206896551722

# %%
less = station_stats.loc[station_stats['install_dockcount'] > station_stats['current_dockcount']]

# %%
len(less)
# Out:
# 11

# %%
greater = station_stats.loc[station_stats['install_dockcount'] < station_stats['current_dockcount']]

# %%
len(greater)
# Out:
# 8

# %% [markdown]
# most stores have less bikes taken out

# %% [markdown]
# how many renters are male and female

# %%
male = trip_stats.loc[trip_stats['gender'] == 'Male']

# %%
len(male)
# Out:
# 140564

# %%
female = trip_stats.loc[trip_stats['gender'] == 'Female']

# %%
len(female)
# Out:
# 37562

# %% [markdown]
# highest humidity

# %%
weather_stats.Max_Humidity.max()
# Out:
# 100

# %% [markdown]
# most common event

# %%
weather_stats.Events.mode()
# Out:
# 0    Rain
# dtype: object
