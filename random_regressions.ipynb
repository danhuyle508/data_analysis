# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import numpy.polynomial.polynomial as poly
from sklearn.model_selection import train_test_split

# render visualizations nicely
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [12.0, 8.0]

# %%
def gen_data(size):
    X = np.random.rand(size) * 100
    Y = X ** 2 + 7
    Y = Y + np.random.randn(Y.shape[0]) * 300
    return X, Y

# %%
X_full,Y_full =gen_data(10)

# %%
X_train, X_test,Y_train, Y_test = train_test_split(df['date'], df['close'], test_size=.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ded0f269905f> in <module>
# ----> 1 X_train, X_test,Y_train, Y_test = train_test_split(df['date'], df['close'], test_size=.2, random_state=42)
#
# NameError: name 'train_test_split' is not defined

# %%
len(X_full)
# Out:
# 10

# %%
plt.plot(X_train, Y_train, 'bo',markersize=5)
plt.title('Training set')
# Out:
# Text(0.5, 1.0, 'Training set')

# %%
plt.plot(X_test, Y_test, 'gs',markersize=5)
plt.title('Training set')
# Out:
# Text(0.5, 1.0, 'Training set')

# %%
coefs_lin = poly.polyfit(X_train,Y_train, 1)
coefs_sq = poly.polyfit(X_train,Y_train, 2)
coefs_ten = poly.polyfit(X_train,Y_train, 10)
# Out:
# /Users/danle/.local/share/virtualenvs/data_analysis-JR90oTg5/lib/python3.7/site-packages/ipykernel_launcher.py:3: RankWarning: The fit may be poorly conditioned
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X_line = np.linspace(0,100)
ffit_ln = poly.polyval(X_line, coefs_lin)
ffit_sq = poly.polyval(X_line, coefs_sq)
ffit_ten = poly.polyval(X_line, coefs_ten)

# %%
plt.ylim(min(Y_train - 5000), max(Y_train +5000))
plt.plot(X_line, ffit_ln, 'g')
plt.plot(X_line, ffit_sq, 'b')
plt.plot(X_line, ffit_ten, 'r')

plt.plot(X_train, Y_train, 'y.', markersize=11)
